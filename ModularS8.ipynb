# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My\ Drive/S8
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/S8

# %%
from torch.optim.lr_scheduler import OneCycleLR
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import OneCycleLR
import matplotlib.pyplot as plt
#%matplotlib inline
import numpy as np
import torchvision
import torchsummary
from torchsummary import summary
import torch

# %%
from data import data
from display import display

from model import ResNet18
#from model import list_summary
from traintest import train , test

# %%
trainset, testset, train_loader, test_loader, classes =data()
# Out:
# CUDA Available? True
# Files already downloaded and verified
# Files already downloaded and verified

# %%
display(train_loader, classes)

# %%
import model
net = model.ResNet18()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
model = net.to(device)
summary(model, input_size=(3, 32, 32))
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
EPOCHS = 20
for epoch in range(EPOCHS):
    print("EPOCH:", epoch)
    train(model,device,train_loader, optimizer, epoch,criterion)
    # scheduler.step()
    test(model, device, test_loader)
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# EPOCH: 0
# Loss=1.0987372398376465 Batch_id=781 Accuracy=44.59: 100%|██████████| 782/782 [01:42<00:00,  6.85it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.4181, Accuracy: 5819/10000 (58.19%)
#
# EPOCH: 1
# Loss=1.349334955215454 Batch_id=781 Accuracy=62.38: 100%|██████████| 782/782 [01:42<00:00,  6.81it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.3415, Accuracy: 6585/10000 (65.85%)
#
# EPOCH: 2
# Loss=0.8400583267211914 Batch_id=781 Accuracy=70.53: 100%|██████████| 782/782 [01:42<00:00,  6.92it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.2773, Accuracy: 7227/10000 (72.27%)
#
# EPOCH: 3
# Loss=0.5724445581436157 Batch_id=781 Accuracy=75.27: 100%|██████████| 782/782 [01:43<00:00,  6.82it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.2506, Accuracy: 7494/10000 (74.94%)
#
# EPOCH: 4
# Loss=0.9457001686096191 Batch_id=781 Accuracy=78.60: 100%|██████████| 782/782 [01:43<00:00,  6.85it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.2662, Accuracy: 7338/10000 (73.38%)
#
# EPOCH: 5
# Loss=0.7676735520362854 Batch_id=781 Accuracy=80.57: 100%|██████████| 782/782 [01:42<00:00,  6.88it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1946, Accuracy: 8054/10000 (80.54%)
#
# EPOCH: 6
# Loss=0.4982489347457886 Batch_id=781 Accuracy=82.43: 100%|██████████| 782/782 [01:43<00:00,  6.92it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1850, Accuracy: 8150/10000 (81.50%)
#
# EPOCH: 7
# Loss=0.48173046112060547 Batch_id=781 Accuracy=84.16: 100%|██████████| 782/782 [01:43<00:00,  6.83it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1863, Accuracy: 8137/10000 (81.37%)
#
# EPOCH: 8
# Loss=0.6483371257781982 Batch_id=781 Accuracy=85.37: 100%|██████████| 782/782 [01:43<00:00,  6.87it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1609, Accuracy: 8391/10000 (83.91%)
#
# EPOCH: 9
# Loss=0.3960472345352173 Batch_id=781 Accuracy=86.15: 100%|██████████| 782/782 [01:43<00:00,  6.86it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1687, Accuracy: 8313/10000 (83.13%)
#
# EPOCH: 10
# Loss=0.16154280304908752 Batch_id=781 Accuracy=87.18: 100%|██████████| 782/782 [01:43<00:00,  6.84it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1438, Accuracy: 8562/10000 (85.62%)
#
# EPOCH: 11
# Loss=0.36761507391929626 Batch_id=781 Accuracy=88.15: 100%|██████████| 782/782 [01:42<00:00,  6.85it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1545, Accuracy: 8455/10000 (84.55%)
#
# EPOCH: 12
# Loss=0.4083712100982666 Batch_id=781 Accuracy=88.78: 100%|██████████| 782/782 [01:43<00:00,  6.72it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1429, Accuracy: 8571/10000 (85.71%)
#
# EPOCH: 13
# Loss=0.5119325518608093 Batch_id=781 Accuracy=89.36: 100%|██████████| 782/782 [01:43<00:00,  6.83it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1456, Accuracy: 8544/10000 (85.44%)
#
# EPOCH: 14
# Loss=0.15097576379776 Batch_id=781 Accuracy=89.94: 100%|██████████| 782/782 [01:42<00:00,  6.82it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1390, Accuracy: 8610/10000 (86.10%)
#
# EPOCH: 15
# Loss=0.557259738445282 Batch_id=781 Accuracy=90.45: 100%|██████████| 782/782 [01:43<00:00,  6.91it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1320, Accuracy: 8680/10000 (86.80%)
#
# EPOCH: 16
# Loss=0.4104296565055847 Batch_id=781 Accuracy=91.05: 100%|██████████| 782/782 [01:43<00:00,  6.81it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1324, Accuracy: 8676/10000 (86.76%)
#
# EPOCH: 17
# Loss=0.36546188592910767 Batch_id=781 Accuracy=91.29: 100%|██████████| 782/782 [01:43<00:00,  6.83it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1256, Accuracy: 8744/10000 (87.44%)
#
# EPOCH: 18
# Loss=0.5683921575546265 Batch_id=781 Accuracy=91.76: 100%|██████████| 782/782 [01:43<00:00,  6.85it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.1249, Accuracy: 8751/10000 (87.51%)
#
# EPOCH: 19
# Loss=0.19599518179893494 Batch_id=781 Accuracy=92.38: 100%|██████████| 782/782 [01:43<00:00,  6.92it/s]
# Test set: Average loss: 0.1201, Accuracy: 8799/10000 (87.99%)

# %%
display(test_loader, classes)
